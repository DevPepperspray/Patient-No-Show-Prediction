# %%
from sklearn.linear_model import LogisticRegression
logistic_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('classifier', LogisticRegression(random_state=42))
])
logistic_params = {
    'classifier__C': [0.1, 1, 10],
    'classifier__solver': ['liblinear', 'lbfgs'],
    'classifier__max_iter': [100, 200]
}
    "\n",
    "logistic_grid = GridSearchCV(logistic_pipeline, logistic_params, cv=5, scoring='accuracy')\n",
    "logistic_grid.fit(X_train_scaled, y_train)\n",
    "\n",
    "print(f\"Best Logistic Regression parameters: {logistic_grid.best_params_}\")\n",
    "logistic_accuracy, logistic_pred = evaluate_model(logistic_grid, X_test_scaled, y_test, \"Logistic Regression\")"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### Model 2: K-Nearest Neighbors"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "from sklearn.neighbors import KNeighborsClassifier\n",
    "\n",
    "knn_pipeline = Pipeline([\n",
    "    ('scaler', StandardScaler()),\n",
    "    ('classifier', KNeighborsClassifier())\n",
    "])\n",
    "\n",
    "knn_params = {\n",
    "    'classifier__n_neighbors': [3, 5, 7, 9, 11],\n",
    "    'classifier__weights': ['uniform', 'distance'],\n",
    "    'classifier__metric': ['euclidean', 'manhattan']\n",
    "}\n",
    "\n",
    "knn_grid = GridSearchCV(knn_pipeline, knn_params, cv=5, scoring='accuracy')\n",
    "knn_grid.fit(X_train_scaled, y_train)\n",
    "\n",
    "print(f\"Best KNN parameters: {knn_grid.best_params_}\")\n",
    "knn_accuracy, knn_pred = evaluate_model(knn_grid, X_test_scaled, y_test, \"KNN\")"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### Model 3: Support Vector Machine"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "from sklearn.svm import SVC\n",
    "\n",
    "svm_pipeline = Pipeline([\n",
    "    ('scaler', StandardScaler()),\n",
    "    ('classifier', SVC(random_state=42, probability=True))\n",
    "])\n",
    "\n",
    "svm_params = {\n",
    "    'classifier__C': [0.1, 1, 10],\n",
    "    'classifier__kernel': ['linear', 'rbf'],\n",
    "    'classifier__gamma': ['scale', 'auto']\n",
    "}\n",
    "\n",
    "svm_grid = GridSearchCV(svm_pipeline, svm_params, cv=5, scoring='accuracy')\n",
    "svm_grid.fit(X_train_scaled, y_train)\n",
    "\n",
    "print(f\"Best SVM parameters: {svm_grid.best_params_}\")\n",
    "svm_accuracy, svm_pred = evaluate_model(svm_grid, X_test_scaled, y_test, \"SVM\")"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### Model 4: Decision Tree"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "from sklearn.tree import DecisionTreeClassifier\n",
    "\n",
    "dt_pipeline = Pipeline([\n",
    "    ('scaler', StandardScaler()),\n",
    "    ('classifier', DecisionTreeClassifier(random_state=42))\n",
    "])\n",
    "\n",
    "dt_params = {\n",
    "    'classifier__max_depth': [3, 5, 7, 10, None],\n",
    "    'classifier__min_samples_split': [2, 5, 10],\n",
    "    'classifier__min_samples_leaf': [1, 2, 4]\n",
    "}\n",
    "\n",
    "dt_grid = GridSearchCV(dt_pipeline, dt_params, cv=5, scoring='accuracy')\n",
    "dt_grid.fit(X_train_scaled, y_train)\n",
    "\n",
    "print(f\"Best Decision Tree parameters: {dt_grid.best_params_}\")\n",
    "dt_accuracy, dt_pred = evaluate_model(dt_grid, X_test_scaled, y_test, \"Decision Tree\")"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### Model 5: Random Forest"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "from sklearn.ensemble import RandomForestClassifier\n",
    "\n",
    "rf_pipeline = Pipeline([\n",
    "    ('scaler', StandardScaler()),\n",
    "    ('classifier', RandomForestClassifier(random_state=42))\n",
    "])\n",
    "\n",
    "rf_params = {\n",
    "    'classifier__n_estimators': [50, 100],\n",
    "    'classifier__max_depth': [5, 10, None],\n",
    "    'classifier__min_samples_split': [2, 5]\n",
    "}\n",
    "\n",
    "rf_grid = GridSearchCV(rf_pipeline, rf_params, cv=5, scoring='accuracy')\n",
    "rf_grid.fit(X_train_scaled, y_train)\n",
    "\n",
    "print(f\"Best Random Forest parameters: {rf_grid.best_params_}\")\n",
    "rf_accuracy, rf_pred = evaluate_model(rf_grid, X_test_scaled, y_test, \"Random Forest\")"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## MODEL COMPARISON & SELECTION"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Compare all models\n",
    "models = ['Logistic Regression', 'KNN', 'SVM', 'Decision Tree', 'Random Forest']\n",
    "accuracies = [logistic_accuracy, knn_accuracy, svm_accuracy, dt_accuracy, rf_accuracy]\n",
    "\n",
    "comparison_df = pd.DataFrame({'Model': models, 'Accuracy': accuracies})\n",
    "comparison_df = comparison_df.sort_values('Accuracy', ascending=False)\n",
    "comparison_df"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Plot model comparison\n",
    "plt.figure(figsize=(10,6))\n",
    "bars = plt.bar(comparison_df['Model'], comparison_df['Accuracy'], color=['gold', 'silver', 'bronze', 'blue', 'green'])\n",
    "plt.xlabel('Model')\n",
    "plt.ylabel('Accuracy')\n",
    "plt.title('Model Performance Comparison')\n",
    "plt.ylim([0.75, 0.85])\n",
    "\n",
    "# Add value labels on bars\n",
    "for bar in bars:\n",
    "    height = bar.get_height()\n",
    "    plt.text(bar.get_x() + bar.get_width()/2., height,\n",
    "             f'{height:.4f}', ha='center', va='bottom')\n",
    "\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Select best model (like in telecom project, we had SVM as best)\n",
    "best_model_name = comparison_df.iloc[0]['Model']\n",
    "best_accuracy = comparison_df.iloc[0]['Accuracy']\n",
    "\n",
    "print(f\"Best model: {best_model_name} with accuracy: {best_accuracy:.4f}\")\n",
    "\n",
    "# Assign best model based on performance\n",
    "if best_model_name == 'Logistic Regression':\n",
    "    best_model = logistic_grid.best_estimator_\n",
    "elif best_model_name == 'KNN':\n",
    "    best_model = knn_grid.best_estimator_\n",
    "elif best_model_name == 'SVM':\n",
    "    best_model = svm_grid.best_estimator_\n",
    "elif best_model_name == 'Decision Tree':\n",
    "    best_model = dt_grid.best_estimator_\n",
    "else:\n",
    "    best_model = rf_grid.best_estimator_"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Save the best model (like in telecom project)\n",
    "joblib.dump(best_model, 'healthcare_model.pkl')\n",
    "print(\"Best model saved as 'healthcare_model.pkl'\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Confusion Matrix for best model\n",
    "best_predictions = best_model.predict(X_test_scaled)\n",
    "cm = confusion_matrix(y_test, best_predictions)\n",
    "\n",
    "plt.figure(figsize=(6,5))\n",
    "sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Showed', 'No-Show'], yticklabels=['Showed', 'No-Show'])\n",
    "plt.xlabel('Predicted')\n",
    "plt.ylabel('Actual')\n",
    "plt.title(f'Confusion Matrix - {best_model_name}')\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# ROC Curve for best model (if model supports predict_proba)\n",
    "if hasattr(best_model, 'predict_proba'):\n",
    "    y_pred_proba = best_model.predict_proba(X_test_scaled)[:, 1]\n",
    "    fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)\n",
    "    roc_auc = roc_auc_score(y_test, y_pred_proba)\n",
    "\n",
    "    plt.figure(figsize=(8,6))\n",
    "    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.4f})')\n",
    "    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')\n",
    "    plt.xlim([0.0, 1.0])\n",
    "    plt.ylim([0.0, 1.05])\n",
    "    plt.xlabel('False Positive Rate')\n",
    "    plt.ylabel('True Positive Rate')\n",
    "    plt.title(f'ROC Curve - {best_model_name}')\n",
    "    plt.legend(loc=\"lower right\")\n",
    "    plt.show()\n",
    "    \n",
    "    print(f\"AUC-ROC Score: {roc_auc:.4f}\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Feature Importance (if model supports it)\n",
    "if best_model_name in ['Decision Tree', 'Random Forest']:\n",
    "    if best_model_name == 'Random Forest':\n",
    "        feature_importance = best_model.named_steps['classifier'].feature_importances_\n",
    "    else:\n",
    "        feature_importance = best_model.named_steps['classifier'].feature_importances_\n",
    "    \n",
    "    feature_names = X.columns\n",
    "    \n",
    "    # Sort features by importance\n",
    "    indices = np.argsort(feature_importance)[::-1]\n",
    "    \n",
    "    plt.figure(figsize=(10,6))\n",
    "    plt.title(f'Feature Importances - {best_model_name}')\n",
    "    plt.bar(range(len(feature_importance)), feature_importance[indices], align='center')\n",
    "    plt.xticks(range(len(feature_importance)), [feature_names[i] for i in indices], rotation=45)\n",
    "    plt.tight_layout()\n",
    "    plt.show()\n",
    "    \n",
    "    # Print feature importance ranking\n",
    "    print(\"Feature Importance Ranking:\")\n",
    "    for i in indices:\n",
    "        print(f\"{feature_names[i]}: {feature_importance[i]:.4f}\")"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## KEY INSIGHTS & RECOMMENDATIONS"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Summary of findings from EDA\n",
    "print(\"=\" * 50)\n",
    "print(\"KEY INSIGHTS FROM PATIENT NO-SHOW ANALYSIS\")\n",
    "print(\"=\" * 50)\n",
    "\n",
    "print(\"\\n1. Wait Time Impact:\")\n",
    "print(f\"   - Patients with longer wait times are more likely to miss appointments\")\n",
    "print(f\"   - Average wait days for no-shows: {df[df['No-show']==1]['WaitDays'].mean():.1f} days\")\n",
    "print(f\"   - Average wait days for shows: {df[df['No-show']==0]['WaitDays'].mean():.1f} days\")\n",
    "\n",
    "print(\"\\n2. SMS Reminder Effectiveness:\")\n",
    "print(f\"   - No-show rate without SMS: {df[df['SMS_received']==0]['No-show'].value_counts(normalize=True).get(1, 0)*100:.2f}%\")\n",
    "print(f\"   - No-show rate with SMS: {df[df['SMS_received']==1]['No-show'].value_counts(normalize=True).get(1, 0)*100:.2f}%\")\n",
    "print(f\"   - SMS reminders reduce no-shows by approximately {df[df['SMS_received']==0]['No-show'].value_counts(normalize=True).get(1, 0)*100 - df[df['SMS_received']==1]['No-show'].value_counts(normalize=True).get(1, 0)*100:.2f}%\")\n",
    "\n",
    "print(\"\\n3. Socioeconomic Factors:\")\n",
    "print(f\"   - Scholarship (welfare) patients: {df[df['Scholarship']==1]['No-show'].value_counts(normalize=True).get(1, 0)*100:.2f}% no-show rate\")\n",
    "print(f\"   - Non-scholarship patients: {df[df['Scholarship']==0]['No-show'].value_counts(normalize=True).get(1, 0)*100:.2f}% no-show rate\")\n",
    "\n",
    "print(\"\\n4. Health Conditions Impact:\")\n",
    "for condition in ['Hypertension', 'Diabetes', 'Alcoholism']:\n",
    "    no_show_rate_with = df[df[condition]==1]['No-show'].value_counts(normalize=True).get(1, 0)*100\n",
    "    no_show_rate_without = df[df[condition]==0]['No-show'].value_counts(normalize=True).get(1, 0)*100\n",
    "    print(f\"   - {condition}: Patients with condition: {no_show_rate_with:.2f}% vs without: {no_show_rate_without:.2f}%\")\n",
    "\n",
    "print(\"\\n5. Age Patterns:\")\n",
    "print(f\"   - Average age of no-shows: {df[df['No-show']==1]['Age'].mean():.1f} years\")\n",
    "print(f\"   - Average age of shows: {df[df['No-show']==0]['Age'].mean():.1f} years\")\n",
    "print(f\"   - Younger patients tend to miss appointments more frequently\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Actionable Recommendations\n",
    "print(\"\\n\" + \"=\" * 50)\n",
    "print(\"ACTIONABLE RECOMMENDATIONS FOR HEALTHCARE PROVIDERS\")\n",
    "print(\"=\" * 50)\n",
    "\n",
    "print(\"\\n1. Reduce Wait Times:\")\n",
    "print(\"   - Implement a policy to schedule appointments within 7 days\")\n",
    "print(\"   - Create a waitlist system to fill cancellations quickly\")\n",
    "print(\"   - Consider telemedicine options for follow-ups to reduce scheduling pressure\")\n",
    "\n",
    "print(\"\\n2. Enhance Reminder Systems:\")\n",
    "print(\"   - Send multiple reminders (SMS, email, phone calls)\")\n",
    "print(\"   - Remind patients 48 hours and 24 hours before appointment\")\n",
    "print(\"   - Include rescheduling options in reminder messages\")\n",
    "\n",
    "print(\"\\n3. Targeted Outreach for High-Risk Groups:\")\n",
    "print(\"   - Welfare patients: Provide transportation assistance or schedule flexibility\")\n",
    "print(\"   - Younger patients: Use mobile apps and digital communication\")\n",
    "print(\"   - Patients with chronic conditions: Regular follow-up calls\")\n",
    "\n",
    "print(\"\\n4. Implement Predictive Risk Scoring:\")\n",
    "print(f\"   - Use the trained model ({best_model_name}) to flag high-risk patients\")\n",
    "print(\"   - Prioritize outreach to patients with >30% predicted no-show probability\")\n",
    "print(\"   - Track intervention effectiveness and refine model periodically\")\n",
    "\n",
    "print(\"\\n5. Operational Improvements:\")\n",
    "print(\"   - Offer Saturday appointments for working patients\")\n",
    "print(\"   - Create a mobile-friendly booking and cancellation system\")\n",
    "print(\"   - Implement a penalty/loyalty program for missed/showed appointments\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Business Impact Estimation\n",
    "print(\"\\n\" + \"=\" * 50)\n",
    "print(\"BUSINESS IMPACT PROJECTION\")\n",
    "print(\"=\" * 50)\n",
    "\n",
    "# Assuming average revenue per appointment\n",
    "avg_revenue_per_appointment = 150  # placeholder value in dollars\n",
    "total_appointments = len(df)\n",
    "current_no_show_rate = df['No-show'].mean() * 100\n",
    "\n",
    "print(f\"\\nCurrent Statistics:\")\n",
    "print(f\"   - Total appointments: {total_appointments}\")\n",
    "print(f\"   - Current no-show rate: {current_no_show_rate:.2f}%\")\n",
    "print(f\"   - Estimated annual revenue loss: ${total_appointments * current_no_show_rate/100 * avg_revenue_per_appointment:,.0f}\")\n",
    "\n",
    "# Projected improvement with intervention\n",
    "target_reduction = 15  # 15% reduction in no-shows\n",
    "projected_no_show_rate = current_no_show_rate * (1 - target_reduction/100)\n",
    "savings = total_appointments * (current_no_show_rate - projected_no_show_rate)/100 * avg_revenue_per_appointment\n",
    "\n",
    "print(f\"\\nProjected Impact with {target_reduction}% No-Show Reduction:\")\n",
    "print(f\"   - New no-show rate: {projected_no_show_rate:.2f}%\")\n",
    "print(f\"   - Annual savings/recovered revenue: ${savings:,.0f}\")\n",
    "print(f\"   - Additional patients served: {int(total_appointments * (current_no_show_rate - projected_no_show_rate)/100)}\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Final model details for deployment\n",
    "print(\"\\n\" + \"=\" * 50)\n",
    "print(\"MODEL DEPLOYMENT SUMMARY\")\n",
    "print(\"=\" * 50)\n",
    "\n",
    "print(f\"\\nBest Model: {best_model_name}\")\n",
    "print(f\"Model Accuracy: {best_accuracy:.4f}\")\n",
    "\n",
    "if best_model_name == 'SVM':\n",
    "    print(f\"Best Parameters: {svm_grid.best_params_}\")\n",
    "elif best_model_name == 'Logistic Regression':\n",
    "    print(f\"Best Parameters: {logistic_grid.best_params_}\")\n",
    "elif best_model_name == 'KNN':\n",
    "    print(f\"Best Parameters: {knn_grid.best_params_}\")\n",
    "elif best_model_name == 'Decision Tree':\n",
    "    print(f\"Best Parameters: {dt_grid.best_params_}\")\n",
    "else:\n",
    "    print(f\"Best Parameters: {rf_grid.best_params_}\")\n",
    "\n",
    "print(\"\\nSaved Files:\")\n",
    "print(\"   - healthcare_scaler.pkl (StandardScaler for preprocessing)\")\n",
    "print(\"   - healthcare_model.pkl (Trained model for predictions)\")\n",
    "\n",
    "print(\"\\nFeature Order (for deployment):\")\n",
    "for i, feature in enumerate(X.columns):\n",
    "    print(f\"   {i+1}. {feature}\")"
